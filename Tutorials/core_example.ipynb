# %%
# !git clone https://github.com/NSCC-COGS/Aestheta.git
# Out:
# Cloning into 'Aestheta'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 76 (delta 31), reused 49 (delta 11), pack-reused 0
# Unpacking objects: 100% (76/76), done.

# %%
# %cd /content/Aestheta/
# !git pull
# Out:
# /content/Aestheta
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/NSCC-COGS/Aestheta
#    bf86243..47efd19  main       -> origin/main
# Updating bf86243..47efd19
# Fast-forward
#  Library/core.py | 1 -
#  1 file changed, 1 deletion(-)

# %%
import Aestheta.Library.core as core
core.getTile(show=True)
# Out:
# 0 0 0
# Array([[[137, 159, 219, 255],
#         [138, 180, 248, 255],
#         [138, 180, 248, 255],
#         ...,
#         [138, 180, 248, 255],
#         [138, 180, 248, 255],
#         [137, 159, 219, 255]],
#
#        [[136, 138, 189, 255],
#         [138, 180, 248, 255],
#         [138, 180, 248, 255],
#         ...,
#         [138, 180, 248, 255],
#         [138, 180, 248, 255],
#         [136, 138, 189, 255]],
#
#        [[136, 138, 189, 255],
#         [138, 180, 248, 255],
#         [138, 180, 248, 255],
#         ...,
#         [138, 180, 248, 255],
#         [138, 180, 248, 255],
#         [136, 138, 189, 255]],
#
#        ...,
#
#        [[206, 178, 181, 255],
#         [208, 210, 213, 255],
#         [208, 210, 213, 255],
#         ...,
#         [208, 210, 213, 255],
#         [208, 210, 213, 255],
#         [206, 178, 181, 255]],
#
#        [[206, 178, 181, 255],
#         [208, 210, 213, 255],
#         [208, 210, 213, 255],
#         ...,
#         [208, 210, 213, 255],
#         [208, 210, 213, 255],
#         [206, 178, 181, 255]],
#
#        [[208, 210, 213, 255],
#         [208, 210, 213, 255],
#         [208, 210, 213, 255],
#         ...,
#         [208, 210, 213, 255],
#         [208, 210, 213, 255],
#         [206, 178, 181, 255]]], dtype=uint8)

# %%
import Aestheta.Library.core as core
core.getTile(xyz=[3,3,3],show=True)
# Out:
# 3 3 3
# Array([[[138, 180, 248, 255],
#         [138, 180, 248, 255],
#         [138, 180, 248, 255],
#         ...,
#         [235, 247, 238, 255],
#         [199, 231, 207, 255],
#         [187, 226, 198, 255]],
#
#        [[138, 180, 248, 255],
#         [138, 180, 248, 255],
#         [138, 180, 248, 255],
#         ...,
#         [229, 244, 233, 255],
#         [187, 226, 198, 255],
#         [187, 226, 198, 255]],
#
#        [[138, 180, 248, 255],
#         [138, 180, 248, 255],
#         [138, 180, 248, 255],
#         ...,
#         [214, 238, 220, 255],
#         [187, 226, 198, 255],
#         [187, 226, 198, 255]],
#
#        ...,
#
#        [[138, 180, 248, 255],
#         [138, 180, 248, 255],
#         [138, 180, 248, 255],
#         ...,
#         [138, 180, 248, 255],
#         [138, 180, 248, 255],
#         [138, 180, 248, 255]],
#
#        [[138, 180, 248, 255],
#         [138, 180, 248, 255],
#         [138, 180, 248, 255],
#         ...,
#         [138, 180, 248, 255],
#         [138, 180, 248, 255],
#         [138, 180, 248, 255]],
#
#        [[136, 138, 189, 255],
#         [136, 138, 189, 255],
#         [136, 138, 189, 255],
#         ...,
#         [138, 180, 248, 255],
#         [138, 180, 248, 255],
#         [136, 138, 189, 255]]], dtype=uint8)
